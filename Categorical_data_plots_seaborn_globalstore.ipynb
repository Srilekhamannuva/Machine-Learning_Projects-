# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd 
import xlrd

# %% [markdown]
# # Load dataset

# %%
 xls = pd.ExcelFile("C:\\Users\\srile\\OneDrive\\Desktop\Global Superstore.xls-1.xls")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\1190669157.py:1: SyntaxWarning: invalid escape sequence '\G'
#   xls = pd.ExcelFile("C:\\Users\\srile\\OneDrive\\Desktop\Global Superstore.xls-1.xls")

# %%
df1=pd.read_excel(xls)

# %%
df1.shape
# Out:
# (51290, 24)

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
import seaborn as sns

# %%
df=df1.loc[0:1000,:]

# %% [markdown]
# # visualizations

# %%
sns.catplot(x='Sales',y='Discount',data=df,palette='rainbow',alpha=1)
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\1961837228.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sales',y='Discount',data=df,palette='rainbow',alpha=1)

# %%
sns.catplot(x='Sales',y='Discount',col='Category',data=df,palette='rainbow',alpha=1)

# %%
sns.lineplot(x='Discount',y='Sales',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Sales'>

# %%
sns.lineplot(x='Discount',y='Profit',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(50, 10))
sns.barplot(x='Sales',y='Profit',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sns.catplot(x='Category',y='Profit',kind="box",data=df,palette='rainbow')
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\2054613948.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Category',y='Profit',kind="box",data=df,palette='rainbow')

# %%
sns.catplot(x='Sub-Category',y='Sales',kind="violin",data=df,palette='rainbow')
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\3202687172.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sub-Category',y='Sales',kind="violin",data=df,palette='rainbow')

# %%
sns.catplot(x='Ship Mode',kind="count",data=df,palette='rainbow')
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\2139815671.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Ship Mode',kind="count",data=df,palette='rainbow')

# %%
sns.catplot(x='Ship Mode',y='Sales',kind="point",data=df)

# %%
sns.catplot(x='Category',y='Profit',kind="swarm",data=df,palette='viridis')
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\4203771847.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Category',y='Profit',kind="swarm",data=df,palette='viridis')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 59.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 52.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 29.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 69.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 62.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 44.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.barplot(x='Sales',y='Discount',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Discount'>

# %%
sns.barplot(x='Sales',y='Profit',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(25,20))
g=sns.barplot(x='Discount',y='Profit',hue='Category',data=df)

# %%
plt.figure(figsize=(25,20))
sns.barplot(x='Discount',y='Profit',hue='Market',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
df2=df.drop(['Row ID','Order ID'],axis=1)

# %%
sns.pairplot(data=df2)

# %%
sns.pairplot(data=df2,hue='Category',palette='rainbow')

# %%
plt.figure(figsize=(25,20))
sns.lineplot(x='Sales',y='Profit',hue='Country',data=df2)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(25,20))
sns.lineplot(x='Sales',y='Discount',hue='Country',data=df2)
# Out:
# <Axes: xlabel='Sales', ylabel='Discount'>

# %%
sns.lmplot(x='Discount',y='Sales',data=df2,  fit_reg=False)

# %%
sns.lmplot(x='Discount',y='Profit',data=df2,  fit_reg=False)

# %%
import numpy as np
df3=df1[['Sales','Profit','Discount']]

# %%
plt.figure(figsize=(50, 30))
sns.heatmap(data=df3,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Sales", y="Profit",
                      hue="Market",
                      data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Discount", y="Profit",
                      hue="Market",
                      data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
colors = ['purple', 'pink', 'green', 'orange','blue','brown']

sns.countplot(x='Market',data=df, alpha=1,palette=colors)
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\526882045.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Market',data=df, alpha=1,palette=colors)
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\526882045.py:3: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='Market',data=df, alpha=1,palette=colors)
# <Axes: xlabel='Market', ylabel='count'>

# %%
colors = ['purple', 'pink', 'green', 'orange','blue','brown']

sns.barplot(x='Market',y='Profit',data=df,palette=colors)
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\1760792538.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Market',y='Profit',data=df,palette=colors)
# C:\Users\srile\AppData\Local\Temp\ipykernel_44320\1760792538.py:3: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Market',y='Profit',data=df,palette=colors)
# <Axes: xlabel='Market', ylabel='Profit'>

# %%
colors = ['purple', 'pink', 'green', 'orange','blue','brown']

sns.boxplot(x='Market',y='Profit',data=df,palette=colors)

# %%
df4=df[["Sales","Profit","Discount","Shipping Cost","Quantity"]]

# %%
df4_corr = df4.corr()

# %%
sns.heatmap(data=df4_corr,cmap="rainbow",annot=True)
